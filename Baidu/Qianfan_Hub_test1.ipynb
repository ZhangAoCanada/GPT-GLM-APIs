# %% [markdown]
# # Exploring the examples of Qianfan Hub
#
# ## Test the pre-existence of Hub/Prompt
#
# See the following examples.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

import qianfan 

# Plugin 智慧图问展示
plugin = qianfan.Plugin(endpoint="f1ks70hdey2ins3u")


resp = plugin.do(plugins=["uuid-chatocr"], query="这上面有什么文字？",fileurl="./images/123.jpg")
# resp = plugin.do(query="你好")
print(resp)
# Out:
# [ERROR] [01-16 18:06:39] openapi_requestor.py:110 [t:140470807848768]: api request req_id:  failed with error code: 337009, err msg: 对不起，当前暂不支持非 BOS 文件的解析，请将图片上传到 BOS 并获取下载链接后再进行重试。, please check https://cloud.baidu.com/doc/WENXINWORKSHOP/s/tlmyncueh
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[2], line 12
#       8 # Plugin 智慧图问展示
#       9 plugin = qianfan.Plugin(endpoint="f1ks70hdey2ins3u")
# ---> 12 resp = plugin.do(plugins=["uuid-chatocr"], query="这上面有什么文字？",fileurl="./images/123.jpg")
#      13 # resp = plugin.do(query="你好")
#      14 print(resp)
#
# File ~/gpts/lib/python3.8/site-packages/qianfan/resources/llm/plugin.py:202, in Plugin.do(self, query, plugins, model, endpoint, stream, retry_count, request_timeout, request_id, backoff_factor, **kwargs)
#     200 if plugins:
#     201     kwargs["plugins"] = plugins
# --> 202 return self._do(
# ...
